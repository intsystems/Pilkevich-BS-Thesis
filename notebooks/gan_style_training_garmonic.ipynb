# %%
from nlp_adapter.train.training import set_up_exp

# %%
set_up_exp(
    data_path='/home/apilkevich/notebooks/mipt/BD/data/input/train.tsv',
    transformer_model_name='./pretrain_detox_s42/bs12_accum1_7500',
    tokenizer_model_name='sberbank-ai/ruT5-base',
    pretrain_adapter_path='./adapter_s42/adapter_1914.pt',
    batch_size=12,
    max_steps=20000,
    dump_model_name='gan_style_training_garmonic/bs12_accum1_s42_m3_ad9',
    report_step=832,
    period_of_dump=832*2,
#     ce_w=1.0,
#     model_w=10.0,
    train_model=True,
    train_adapter=True,
    seed=42,
    test_size=0.1,
    device='1',
    loss_mode='prod',
    model_lr=1e-5,
    adapter_lr=1e-3,
    num_accum_steps=1,
    model_period_train=3,
    adapter_period_train=9,    
)
# Out:
# Start loading models...
# All models are loading.
#
# Start preparing data...
# Load dataset from file:   0%|          | 0/6948 [00:00<?, ?it/s]
# All data are ready.
#
# Start training...
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 0/1000, epoch_step 831/832, global_step 832/20000
# ce train loss: 0.5625, model train loss: 0.9597, kl loss: 0.0353
# ce val loss: 1.2253, model val loss: 0.9745
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 1/1000, epoch_step 831/832, global_step 1664/20000
# ce train loss: 0.5749, model train loss: 0.9628, kl loss: 0.0244
# ce val loss: 1.2323, model val loss: 0.9668
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 2/1000, epoch_step 831/832, global_step 2496/20000
# ce train loss: 0.5503, model train loss: 0.9632, kl loss: 0.0252
# ce val loss: 1.2264, model val loss: 0.9703
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 3/1000, epoch_step 831/832, global_step 3328/20000
# ce train loss: 0.5941, model train loss: 0.9555, kl loss: 0.0411
# ce val loss: 1.2403, model val loss: 0.9664
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 4/1000, epoch_step 831/832, global_step 4160/20000
# ce train loss: 0.5987, model train loss: 0.9648, kl loss: 0.0249
# ce val loss: 1.2674, model val loss: 0.9826
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 5/1000, epoch_step 831/832, global_step 4992/20000
# ce train loss: 0.6069, model train loss: 0.9635, kl loss: 0.0249
# ce val loss: 1.2560, model val loss: 0.9758
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 6/1000, epoch_step 831/832, global_step 5824/20000
# ce train loss: 0.5173, model train loss: 0.9644, kl loss: 0.0309
# ce val loss: 1.2722, model val loss: 0.9658
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 7/1000, epoch_step 831/832, global_step 6656/20000
# ce train loss: 0.5792, model train loss: 0.9666, kl loss: 0.0266
# ce val loss: 1.2679, model val loss: 0.9471
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 8/1000, epoch_step 831/832, global_step 7488/20000
# ce train loss: 0.5136, model train loss: 0.9558, kl loss: 0.0307
# ce val loss: 1.2909, model val loss: 0.9634
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 9/1000, epoch_step 831/832, global_step 8320/20000
# ce train loss: 0.5441, model train loss: 0.9544, kl loss: 0.0356
# ce val loss: 1.2707, model val loss: 0.9686
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 10/1000, epoch_step 831/832, global_step 9152/20000
# ce train loss: 0.5918, model train loss: 0.9681, kl loss: 0.0289
# ce val loss: 1.2811, model val loss: 0.9772
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 11/1000, epoch_step 831/832, global_step 9984/20000
# ce train loss: 0.5870, model train loss: 0.9674, kl loss: 0.0249
# ce val loss: 1.2811, model val loss: 0.9680
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 12/1000, epoch_step 831/832, global_step 10816/20000
# ce train loss: 0.5697, model train loss: 0.9675, kl loss: 0.0186
# ce val loss: 1.2977, model val loss: 0.9717
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 13/1000, epoch_step 831/832, global_step 11648/20000
# ce train loss: 0.5811, model train loss: 0.9606, kl loss: 0.0195
# ce val loss: 1.3000, model val loss: 0.9531
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 14/1000, epoch_step 831/832, global_step 12480/20000
# ce train loss: 0.5558, model train loss: 0.9704, kl loss: 0.0179
# ce val loss: 1.3060, model val loss: 0.9626
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 15/1000, epoch_step 831/832, global_step 13312/20000
# ce train loss: 0.5663, model train loss: 0.9584, kl loss: 0.0181
# ce val loss: 1.3131, model val loss: 0.9650
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 16/1000, epoch_step 831/832, global_step 14144/20000
# ce train loss: 0.5696, model train loss: 0.9623, kl loss: 0.0156
# ce val loss: 1.3025, model val loss: 0.9790
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 17/1000, epoch_step 831/832, global_step 14976/20000
# ce train loss: 0.5353, model train loss: 0.9630, kl loss: 0.0092
# ce val loss: 1.2941, model val loss: 0.9727
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 18/1000, epoch_step 831/832, global_step 15808/20000
# ce train loss: 0.5195, model train loss: 0.9651, kl loss: 0.0128
# ce val loss: 1.3238, model val loss: 0.9719
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 19/1000, epoch_step 831/832, global_step 16640/20000
# ce train loss: 0.5428, model train loss: 0.9685, kl loss: 0.0099
# ce val loss: 1.3079, model val loss: 0.9634
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# /home/apilkevich/pycharm/BachelorDegree/nlp_adapter/train/training.py:159: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(18, 9), constrained_layout=False)
# epoch 20/1000, epoch_step 831/832, global_step 17472/20000
# ce train loss: 0.4895, model train loss: 0.9728, kl loss: 0.0122
# ce val loss: 1.2952, model val loss: 0.9692
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 21/1000, epoch_step 831/832, global_step 18304/20000
# ce train loss: 0.4713, model train loss: 0.9712, kl loss: 0.0095
# ce val loss: 1.3120, model val loss: 0.9726
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 22/1000, epoch_step 831/832, global_step 19136/20000
# ce train loss: 0.5213, model train loss: 0.9730, kl loss: 0.0120
# ce val loss: 1.3298, model val loss: 0.9617
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# epoch 23/1000, epoch_step 831/832, global_step 19968/20000
# ce train loss: 0.5313, model train loss: 0.9743, kl loss: 0.0083
# ce val loss: 1.3134, model val loss: 0.9728
#   0%|          | 0/832 [00:00<?, ?it/s]
# /home/apilkevich/envs/conda_ds/lib/python3.7/site-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."

# %%
from nlp_adapter.evaluation.evaluation import inference

# %%
inference(
    data_path='/home/apilkevich/notebooks/mipt/BD/data/input/dev.tsv',
    model_name='./gan_style_training_garmonic/bs12_accum3_s42_m3_ad9_3328',
    tokenizer_model_name='sberbank-ai/ruT5-base',
    result_path='/home/apilkevich/notebooks/mipt/BD/data/output/bs12_accum3_s42_m3_ad9_3328_garm.txt',
    device='1',
)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
from nlp_adapter.evaluation.evaluation import evaluate_and_dump

# %%
evaluate_and_dump(
    gold_label_path='/home/apilkevich/notebooks/mipt/BD/data/input/dev.tsv',
    predicts_path='/home/apilkevich/notebooks/mipt/BD/data/output/bs12_accum3_s42_m3_ad9_3328_garm.txt',
    name='bs12_accum3_s42_m3_ad9_11648_garm',
    output_path='./results.md',
    batch_size=32,
    device='1',
)
# Out:
# Load data...
# Load models...
# Some weights of the model checkpoint at cointegrated/LaBSE-en-ru were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Style evaluation
#   0%|          | 0/25 [00:00<?, ?it/s]
# Meaning evaluation
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Fluency evaluation
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# {'accuracy': 0.6997146606445312,
#  'similarity': 0.8046112656593323,
#  'fluency': 0.7782630920410156,
#  'joint': 0.43771713972091675,
#  'chrf': 0.56997699903469,
#  'accuracy_chrf': 0.3988212624547464}

# %% [markdown]
# | Model | ACC | SIM | FL | J | ChrF1 | Acc*ChrF1 |
# | ----- | --- | --- | -- | - | ----- | --------- |
# pretrain_s10000_bs8_s42|0.7580|0.7998|0.8037|0.4918|0.5721|0.4336|
# posttrain_model_loss_s1387_bs8_s1387|0.9851|0.0000|0.4909|0.0000|0.0985|0.0970|
# ce1_m10_bs8_10000_s42|0.7893|0.7749|0.7800|0.4861|0.5647|0.4457|
# ce1_m10_bs8_s42_12500_garmonic|0.7702|0.7847|0.7985|0.4920|0.5728|0.4412|
